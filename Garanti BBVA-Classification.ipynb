# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("C://Users/Furkan/Desktop/onlinedatasciencechallenge/train.csv")
test_input = pd.read_csv("C://Users/Furkan/Desktop/onlinedatasciencechallenge/test_input.csv")
testcolumns = ['ACCAMNTAVG03', 'CRRASTALL', 'DESACCUAMNT',
            'CONTPAIDAMNT00', 'CONTPAIDAMNT01', 'CONTPAIDAMNT02',
       'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05', 'CONTPAIDAMNT06',
       'CONTPAIDAMNT08', 'CONTPAIDAMNT09', 'CONTPAIDAMNT10', 'CONTPAIDAMNT11',
       'CONTMONTHAMNT', 'RTRNDESVAMNT', 'CONTCOLLAMNT']

columns2 = ['ADDCONTAMNT','ACCAMNTAVG03', 'CRRASTALL', 'DESACCUAMNT',
            'CONTPAIDAMNT00', 'CONTPAIDAMNT01', 'CONTPAIDAMNT02',
       'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05', 'CONTPAIDAMNT06',
       'CONTPAIDAMNT08', 'CONTPAIDAMNT09', 'CONTPAIDAMNT10', 'CONTPAIDAMNT11',
       'CONTMONTHAMNT', 'RTRNDESVAMNT', 'CONTCOLLAMNT']

col3 = ["ACCMVMTAVG","ACCAMNTAVG03","ACCACVNUM12","ACCAMNTAVG12","CARDDINSUM12","CRRASTALL","ASTAVGDIF0312","MAXMATEVR","LSTPRDCNUM",'CONTPAIDAMNT00', 'CONTPAIDAMNT01', 'CONTPAIDAMNT02',
       'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05', 'CONTPAIDAMNT06',
       'CONTPAIDAMNT08', 'CONTPAIDAMNT09', 'CONTPAIDAMNT10', 'CONTPAIDAMNT11']

all = ['ADDCONTAMNT', 'ACCMVMTAVG', 'ACCAMNTAVG03',
       'ACCACVNUM12', 'ACCAMNTAVG12', 'CARDDINSUM12', 'DISTNUM12',
       'INTPHNNUM03', 'INTLOGNUM12', 'DEMINFO1', 'DEMINFO2',
       'CRRASTALL', 'ASTAVGDIF0312', 'MAXMATEVR',
       'LSTPRDCNUM', 'DESACCUAMNT', 'CONTPAIDAMNT00', 'CONTPAIDAMNT01',
       'CONTPAIDAMNT02', 'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05',
       'CONTPAIDAMNT06', 'CONTPAIDAMNT08', 'CONTPAIDAMNT09',
       'CONTPAIDAMNT10', 'CONTPAIDAMNT11', 'CONTDEBTNUM', 'CONTMONTHAMNT',
       'RTRNDESVAMNT', 'MAXTIMECONTR', 'CONTCOLLAMNT']
alltest = ['ACCMVMTAVG', 'ACCAMNTAVG03',
       'ACCACVNUM12', 'ACCAMNTAVG12', 'CARDDINSUM12', 'DISTNUM12',
       'INTPHNNUM03', 'INTLOGNUM12', 'DEMINFO1', 'DEMINFO2',
       'CRRASTALL', 'ASTAVGDIF0312', 'MAXMATEVR',
       'LSTPRDCNUM', 'DESACCUAMNT', 'CONTPAIDAMNT00', 'CONTPAIDAMNT01',
       'CONTPAIDAMNT02', 'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05',
       'CONTPAIDAMNT06', 'CONTPAIDAMNT08', 'CONTPAIDAMNT09',
       'CONTPAIDAMNT10', 'CONTPAIDAMNT11', 'CONTDEBTNUM', 'CONTMONTHAMNT',
       'RTRNDESVAMNT', 'MAXTIMECONTR', 'CONTCOLLAMNT']

# %%
train_col = train_data[all]
test_col = test_input[alltest]

# %%
test_col.isnull().sum()
# Out:
# ACCMVMTAVG        3218
# ACCAMNTAVG03      3395
# ACCACVNUM12       1846
# ACCAMNTAVG12      4049
# CARDDINSUM12      4952
# DISTNUM12            0
# INTPHNNUM03          0
# INTLOGNUM12          0
# DEMINFO1             0
# DEMINFO2             0
# CRRASTALL           88
# ASTAVGDIF0312      403
# MAXMATEVR          779
# LSTPRDCNUM          35
# DESACCUAMNT          0
# CONTPAIDAMNT00    4623
# CONTPAIDAMNT01    4623
# CONTPAIDAMNT02    4623
# CONTPAIDAMNT03    4623
# CONTPAIDAMNT04    4623
# CONTPAIDAMNT05    4623
# CONTPAIDAMNT06    4623
# CONTPAIDAMNT08    4623
# CONTPAIDAMNT09    4623
# CONTPAIDAMNT10    4623
# CONTPAIDAMNT11    4623
# CONTDEBTNUM          0
# CONTMONTHAMNT        0
# RTRNDESVAMNT         0
# MAXTIMECONTR         0
# CONTCOLLAMNT         0
# dtype: int64

# %%
for i in col3:
    median = train_col.loc[train_col["ADDCONTAMNT"] == 0].median()[i]
    train_col.loc[train_col[i].isnull(), i] = median
    test_col.loc[test_col[i].isnull(), i] = median

#train_col.loc[train_col["ACCAMNTAVG03"].isnull(), "ACCAMNTAVG03"] = train_col["ACCAMNTAVG03"].mean()
#test_col.loc[test_col["ACCAMNTAVG03"].isnull(), "ACCAMNTAVG03"] = test_col["ACCAMNTAVG03"].mean()

# %%
y = train_col["ADDCONTAMNT"]
train_col.drop("ADDCONTAMNT",axis=1,inplace=True)

# %%
train_col.loc[train_col.ADDCONTAMNT != 0, "ADDCONTAMNT"] =1

# %%
print(train_col.shape)
print(test_col.shape)
# Out:
# (173589, 31)
# (16978, 31)

# %% [markdown]
# ### 'CONTPAIDAMNT07' kolonunun test veri setinde eksik olduğunu görüyoruz ve verilerden atıyoruz.

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 173584    0
# 173585    0
# 173586    1
# 173587    1
# 173588    0
# Name: ADDCONTAMNT, Length: 173589, dtype: int64

# %%
train_data.drop('CONTPAIDAMNT07', axis=1, inplace=True)
train_data.head()
# Out:
#    ACCMVMTAVG  ACCAMNTAVG03  ACCACVNUM12  ACCAMNTAVG12  CARDDINSUM12  \
# 0       641.0           NaN        100.0         396.0         204.0
# 1     50477.0         122.0        100.0           NaN         100.0
# 2      1461.0        1593.0        108.0        2268.0         203.0
# 3      9723.0         111.0        100.0        7173.0         100.0
# 4      2124.0           NaN        100.0        2498.0           NaN
#
#    DISTNUM12  INTPHNNUM03  INTLOGNUM12  DEMINFO1  DEMINFO2  ...  \
# 0        100          100          100        57         2  ...
# 1        107          258          126        36         2  ...
# 2        117          779          328        37         2  ...
# 3        123          316          164        58         3  ...
# 4        100          129          356        36         2  ...
#
#    CONTPAIDAMNT10  CONTPAIDAMNT11  CONTDEBTNUM  CONTMONTHAMNT  RTRNDESVAMNT  \
# 0           310.0             0.0          104            340           272
# ...

# %%
corr_df = pd.DataFrame(train_data.corr())
corr_df.shape
# Out:
# (39, 39)

# %%
columns = corr_df.loc[corr_df.ADDCONTAMNT > 0.01].index

# %%
columns =columns.drop(["CUSTNBR","ADDCONTAMNT","CONTPAIDAMNT07"])
columns
# Out:
# Index(['ACCMVMTAVG', 'ACCAMNTAVG03', 'ACCACVNUM12', 'ACCAMNTAVG12',
#        'CARDDINSUM12', 'INTPHNNUM03', 'INTLOGNUM12', 'DEMINFO1', 'DEMINFO2',
#        'BLNAMNT03', 'CRRASTALL', 'ASTAVGDIF0312', 'EFTAMNTSUM12', 'DEBTAVG00',
#        'DESACCUAMNT', 'CONTPAIDAMNT00', 'CONTPAIDAMNT01', 'CONTPAIDAMNT02',
#        'CONTPAIDAMNT03', 'CONTPAIDAMNT04', 'CONTPAIDAMNT05', 'CONTPAIDAMNT06',
#        'CONTPAIDAMNT08', 'CONTPAIDAMNT09', 'CONTPAIDAMNT10', 'CONTPAIDAMNT11',
#        'CONTMONTHAMNT', 'RTRNDESVAMNT', 'MAXTIMECONTR', 'CONTCOLLAMNT',
#        'TIMEDEPAVG12'],
#       dtype='object')

# %%
train_col = train_data[columns]
test_col = test_data[columns]

# %%
train_col.isnull().sum()
# Out:
# ACCMVMTAVG        33109
# ACCAMNTAVG03      35080
# ACCACVNUM12       19012
# ACCAMNTAVG12      41366
# CARDDINSUM12      49592
# INTPHNNUM03           0
# INTLOGNUM12           0
# DEMINFO1              0
# DEMINFO2              0
# CRRASTALL          1104
# ASTAVGDIF0312      5559
# DESACCUAMNT           0
# CONTPAIDAMNT00    44634
# CONTPAIDAMNT01    44634
# CONTPAIDAMNT02    44634
# CONTPAIDAMNT03    44634
# CONTPAIDAMNT04    44634
# CONTPAIDAMNT05    44634
# CONTPAIDAMNT06    44634
# CONTPAIDAMNT08    44634
# CONTPAIDAMNT09    44634
# CONTPAIDAMNT10    44634
# CONTPAIDAMNT11    44634
# CONTMONTHAMNT         0
# RTRNDESVAMNT          0
# MAXTIMECONTR          0
# CONTCOLLAMNT          0
# dtype: int64

# %%
for col in train_data.columns:
    print(col, str(round(100* train_data[col].isnull().sum() / len(train_data), 2)) + '%')
# Out:
# ACCMVMTAVG 19.07%
# ACCAMNTAVG03 20.21%
# ACCACVNUM12 10.95%
# ACCAMNTAVG12 23.83%
# CARDDINSUM12 28.57%
# DISTNUM12 0.0%
# INTPHNNUM03 0.0%
# INTLOGNUM12 0.0%
# DEMINFO1 0.0%
# DEMINFO2 0.0%
# BLNAMNT03 90.91%
# CRRASTALL 0.64%
# ASTAVGDIF0312 3.2%
# EFTAMNTSUM12 50.14%
# MAXMATEVR 4.78%
# DEBTAVG00 51.32%
# LSTPRDCNUM 0.28%
# DESACCUAMNT 0.0%
# CONTPAIDAMNT00 25.71%
# CONTPAIDAMNT01 25.71%
# CONTPAIDAMNT02 25.71%
# CONTPAIDAMNT03 25.71%
# CONTPAIDAMNT04 25.71%
# CONTPAIDAMNT05 25.71%
# CONTPAIDAMNT06 25.71%
# CONTPAIDAMNT08 25.71%
# CONTPAIDAMNT09 25.71%
# CONTPAIDAMNT10 25.71%
# CONTPAIDAMNT11 25.71%
# CONTDEBTNUM 0.0%
# CONTMONTHAMNT 0.0%
# RTRNDESVAMNT 0.0%
# MAXTIMECONTR 0.0%
# CONTCOLLAMNT 0.0%
# LASTAUTOPAYTIME 61.78%
# TIMEDEPAVG12 78.78%
# ADDCONTAMNT 0.0%

# %% [markdown]
# #### Bundan sonrası ayrışıyor. 1) null satırları çıkarıcaz 2) null.df.mean() ortalamalarını alalım

# %%
train_mean = train_col.fillna(train_col.mean())
test_mean = test_col.fillna(test_col.mean())

train_median = train_col.fillna(train_col.median())
test_median = test_col.fillna(test_col.median())

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_col, y, test_size=0.3, random_state=8)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(max_depth=4, criterion = "mse", min_samples_split = 2,min_samples_leaf= 20)
dtr.fit(x_train,y_train)
dtr_pred = dtr.predict(x_test)
#dtr3_pred = dtr.predict(test_col)
print("1")
print("R^2 Score: " + str(r2_score(y_test,dtr_pred)))
print("RMSE: " + str(mean_squared_error(y_test,dtr_pred, squared=False)))
# Out:
# 1
# R^2 Score: 0.12658063431792332
# RMSE: 7497.734989328824

# %%
from sklearn.model_selection import GridSearchCV
p = {"criterion" : ["mse", "mae"], 
      "max_depth" : [None, 2,7,20], 
      "min_samples_split":[2,5,10,40],
      "min_samples_leaf":[2,10,40]      
     }
gs = GridSearchCV(dtr, p, scoring = "neg_mean_squared_error", cv =5, n_jobs = -1 )
gs.fit(x_train, y_train)
best = grid_search.best_score_             #   // en iyi scoreu verir
bestparam = grid_search.best_params_  # // en iyi çalıştığı parametreleri verir
print("Best Score:")
print(best)
print("Best Param:")
print(bestparam)

# %%
gs.best_params_
# Out:
# {'criterion': 'mse'}

# %% [markdown]
# ### "BLNAMNT03", "EFTAMNTSUM12","DEBTAVG00" "LASTAUTOPAYTIME", "TIMEDEPAVG12" kolonlarını eksik veriden dolayı atmak zorundayız.
# ## Veri kaybının %50'den fazla olduğu kolonlar

# %%
train_data.drop(["BLNAMNT03","EFTAMNTSUM12","DEBTAVG00","LASTAUTOPAYTIME","TIMEDEPAVG12"], axis=1, inplace=True)
test_data.drop(["BLNAMNT03","EFTAMNTSUM12","DEBTAVG00","LASTAUTOPAYTIME","TIMEDEPAVG12"], axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', None)

train_data.describe()
# Out:
#          ACCMVMTAVG  ACCAMNTAVG03    ACCACVNUM12  ACCAMNTAVG12   CARDDINSUM12  \
# count  1.404800e+05  1.385090e+05  154577.000000  1.322230e+05  123997.000000
# mean   1.176651e+04  1.233938e+04      89.568875  6.169715e+03    2232.150375
# std    1.207733e+05  1.175202e+05      33.449373  2.244941e+04    7517.708537
# min    1.000000e+02  1.000000e+02       0.000000  1.600000e+02     100.000000
# 25%    1.017000e+03  1.760000e+02     100.000000  7.720000e+02     100.000000
# 50%    2.169000e+03  7.850000e+02     100.000000  1.804000e+03     309.000000
# 75%    6.056000e+03  3.944000e+03     100.000000  4.614000e+03    1440.000000
# max    1.628313e+07  2.036765e+07    1166.000000  2.023282e+06  604713.000000
#
#            DISTNUM12    INTPHNNUM03    INTLOGNUM12       DEMINFO1  \
# count  173589.000000  173589.000000  173589.000000  173589.000000
# mean      124.800022     553.256710     259.088773      50.554494
# std        47.677580     775.273702     269.563549      11.334910
# ...

# %%
train_data = train_data.dropna(how="any",axis=0)

# %%
train_data.isnull().sum()
# Out:
# ACCMVMTAVG        33109
# ACCAMNTAVG03      35080
# ACCACVNUM12       19012
# ACCAMNTAVG12      41366
# CARDDINSUM12      49592
# DISTNUM12             0
# INTPHNNUM03           0
# INTLOGNUM12           0
# DEMINFO1              0
# DEMINFO2              0
# CRRASTALL          1104
# ASTAVGDIF0312      5559
# MAXMATEVR          8293
# LSTPRDCNUM          485
# DESACCUAMNT           0
# CONTPAIDAMNT00    44634
# CONTPAIDAMNT01    44634
# CONTPAIDAMNT02    44634
# CONTPAIDAMNT03    44634
# CONTPAIDAMNT04    44634
# CONTPAIDAMNT05    44634
# CONTPAIDAMNT06    44634
# CONTPAIDAMNT08    44634
# CONTPAIDAMNT09    44634
# CONTPAIDAMNT10    44634
# CONTPAIDAMNT11    44634
# CONTDEBTNUM           0
# CONTMONTHAMNT         0
# RTRNDESVAMNT          0
# MAXTIMECONTR          0
# CONTCOLLAMNT          0
# ADDCONTAMNT           0
# dtype: int64

# %%
train_data.corr()
# Out:
#                 ACCMVMTAVG  ACCAMNTAVG03  ACCACVNUM12  ACCAMNTAVG12  \
# ACCMVMTAVG        1.000000      0.102946    -0.005619      0.118737
# ACCAMNTAVG03      0.102946      1.000000     0.024232      0.280420
# ACCACVNUM12      -0.005619      0.024232     1.000000      0.023795
# ACCAMNTAVG12      0.118737      0.280420     0.023795      1.000000
# CARDDINSUM12      0.105420      0.123451     0.039201      0.106781
# DISTNUM12         0.011021      0.001200     0.138778     -0.003479
# INTPHNNUM03       0.038421      0.071613     0.216191      0.129550
# INTLOGNUM12       0.036755      0.053259     0.224588      0.119780
# DEMINFO1          0.038812      0.046210     0.006971      0.050335
# DEMINFO2          0.071542      0.055516     0.024584      0.108467
# CRRASTALL         0.338961      0.310032     0.026912      0.106095
# ASTAVGDIF0312     0.059721      0.204205     0.007206      0.036466
# MAXMATEVR        -0.047085     -0.052899     0.000096     -0.059060
# ...

# %%
corr_matrix = train_data.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] < 0.01)]
# Drop features 
data1 = train_data.drop(train_data[to_drop], axis=1)
test1 = test_data.drop(test_data[to_drop], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b2fd8d4ff765> in <module>
#       7 # Drop features
#       8 data1 = train_data.drop(train_data[to_drop], axis=1)
# ----> 9 test1 = test_data.drop(test_data[to_drop], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
# ...

# %%
train_data.fillna(train_data.mean(),inplace=True)
test_data.fillna(test_data.mean(),inplace=True)

# %%
train_data.describe().T
# Out:
#                    count          mean            std         min     25%  \
# ACCMVMTAVG      173589.0  11766.509774  108646.792524       100.0  1229.0
# ACCAMNTAVG03    173589.0  12339.375420  104975.980772       100.0   254.0
# ACCACVNUM12     173589.0     89.568875      31.564519         0.0   100.0
# ACCAMNTAVG12    173589.0   6169.715125   19592.820879       160.0  1012.0
# CARDDINSUM12    173589.0   2232.150375    6353.740480       100.0   129.0
# DISTNUM12       173589.0    124.800022      47.677580       100.0   100.0
# INTPHNNUM03     173589.0    553.256710     775.273702       100.0   100.0
# INTLOGNUM12     173589.0    259.088773     269.563549       100.0   100.0
# DEMINFO1        173589.0     50.554494      11.334910        27.0    42.0
# DEMINFO2        173589.0      2.148598       0.732367         1.0     2.0
# CRRASTALL       173589.0  76311.157457  795833.440279       100.0   866.0
# ASTAVGDIF0312   173589.0  10891.650390  416803.862669 -77869836.0    76.0
# ...

# %% [markdown]
# ### Outlier değerlerden kurtulmak için IsolationForest kullanıyoruz.

# %%
from sklearn.ensemble import IsolationForest
iso = IsolationForest(contamination=0.25)
yhat = iso.fit_predict(train_data)

# %%
mask = yhat != -1

train_inlier = train_data.iloc[mask,:]

# %%
train_inlier.describe().T
# Out:
#                    count          mean           std        min     25%  \
# ACCMVMTAVG      130192.0   5619.476819   7677.279982      100.0  1060.0
# ACCAMNTAVG03    130192.0   5240.354677   8850.095258      100.0   203.0
# ACCACVNUM12     130192.0     88.440316     31.863724        0.0   100.0
# ACCAMNTAVG12    130192.0   3994.492491   4771.758163      160.0   893.0
# CARDDINSUM12    130192.0   1423.283437   2100.768601      100.0   100.0
# DISTNUM12       130192.0    122.117173     38.747787      100.0   100.0
# INTPHNNUM03     130192.0    435.364032    478.300540      100.0   100.0
# INTLOGNUM12     130192.0    219.261091    175.426162      100.0   100.0
# DEMINFO1        130192.0     49.226796     10.732307       27.0    41.0
# DEMINFO2        130192.0      2.108809      0.519091        1.0     2.0
# CRRASTALL       130192.0  14691.767968  46063.976533      100.0   627.0
# ASTAVGDIF0312   130192.0   1847.960854  26298.268083 -4447136.0    74.0
# ...

# %%
train_inlier.corr()
# Out:
#                 ACCMVMTAVG  ACCAMNTAVG03  ACCACVNUM12  ACCAMNTAVG12  \
# ACCMVMTAVG        1.000000      0.239126    -0.286570      0.336596
# ACCAMNTAVG03      0.239126      1.000000    -0.056416      0.464010
# ACCACVNUM12      -0.286570     -0.056416     1.000000     -0.148561
# ACCAMNTAVG12      0.336596      0.464010    -0.148561      1.000000
# CARDDINSUM12      0.108820      0.092271    -0.034423      0.052544
# DISTNUM12        -0.097752     -0.054618     0.153709     -0.051489
# INTPHNNUM03      -0.054827      0.025534     0.249196      0.024928
# INTLOGNUM12      -0.067653      0.006849     0.249736      0.024116
# DEMINFO1          0.054049      0.049974     0.007360      0.030174
# DEMINFO2          0.077640     -0.013280     0.007830      0.068529
# CRRASTALL         0.136794      0.239679     0.045718      0.121370
# ASTAVGDIF0312    -0.001329      0.145630     0.006428      0.015929
# MAXMATEVR        -0.072474     -0.063706    -0.001427     -0.042508
# ...

# %%
train_data.loc[train_data.ADDCONTAMNT != 0, "ADDCONTAMNT"] = 1
#train_inlier.loc[train_inlier.ADDCONTAMNT != 0, "ADDCONTAMNT"] = 1

# %%
train_data.head()
#train_inlier.head()
# Out:
#    ACCMVMTAVG  ACCAMNTAVG03  ACCACVNUM12  ACCAMNTAVG12  CARDDINSUM12  \
# 2      1461.0        1593.0        108.0        2268.0         203.0
# 3      9723.0         111.0        100.0        7173.0         100.0
# 6      1138.0         870.0        100.0         988.0         173.0
# 8      1380.0         470.0        101.0         700.0         126.0
# 9      1295.0         287.0        100.0         492.0         100.0
#
#    DISTNUM12  INTPHNNUM03  INTLOGNUM12  DEMINFO1  DEMINFO2  ...  \
# 2        117          779          328        37         2  ...
# 3        123          316          164        58         3  ...
# 6        105          100          100        48         2  ...
# 8        104          542          304        39         2  ...
# 9        101          372          160        35         2  ...
#
#    CONTPAIDAMNT08  CONTPAIDAMNT09  CONTPAIDAMNT10  CONTPAIDAMNT11  \
# 2           436.0           268.0           556.0             0.0
# ...

# %%
y_data2 = train_data.iloc[:,-1]
#y_inlier = train_inlier.iloc[:,-1]

# %%
train_data.drop("ADDCONTAMNT",axis=1, inplace=True)
#train_inlier.drop("ADDCONTAMNT",axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_data, y_data, test_size=0.3, random_state=8)
#x_train, x_test, y_train, y_test = train_test_split(train_inlier, y_inlier, test_size=0.3, random_state=8)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix

# %%
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(random_state = 0)
logreg.fit(x_train, y_train)
logreg_pred = logreg.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,logreg_pred)))
print("RMSE: " + str(mean_squared_error(y_test,logreg_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,logreg_pred))
# Out:
# R^2 Score: -0.0463052594418214
# RMSE: 0.35155315330723164
# Confusion matrix:
# [[21192   228]
#  [ 2839   557]]
# C:\Users\Furkan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
"""
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train,y_train)
knn_pred = knn.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,knn_pred)))
print("RMSE: " + str(mean_squared_error(y_test,knn_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,knn_pred))
"""
# Out:
# '\nfrom sklearn.neighbors import KNeighborsClassifier\nknn = KNeighborsClassifier(n_neighbors = 3)\nknn.fit(x_train,y_train)\nknn_pred = knn.predict(x_test)\n\nprint("R^2 Score: " + str(r2_score(y_test,knn_pred)))\nprint("RMSE: " + str(mean_squared_error(y_test,knn_pred, squared=False)))\nprint("Confusion matrix:")\nprint(confusion_matrix(y_test,knn_pred))\n'

# %%
"""
from sklearn.svm import SVC
svc = SVC(kernel="linear")
svc.fit(x_train,y_train)
svc_pred = svc.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,svc_pred)))
print("RMSE: " + str(mean_squared_error(y_test,svc_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,svc_pred))
"""
# Out:
# '\nfrom sklearn.svm import SVC\nsvc = SVC(kernel="linear")\nsvc.fit(x_train,y_train)\nsvc_pred = svc.predict(x_test)\n\nprint("R^2 Score: " + str(r2_score(y_test,svc_pred)))\nprint("RMSE: " + str(mean_squared_error(y_test,svc_pred, squared=False)))\nprint("Confusion matrix:")\nprint(confusion_matrix(y_test,svc_pred))\n'

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,gnb_pred)))
print("RMSE: " + str(mean_squared_error(y_test,gnb_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,gnb_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1907b7047da3> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 gnb = GaussianNB
# ----> 3 gnb.fit(x_train, y_train)
#       4 gnb_pred = gnb.predict(x_test)
#       5
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth= 7, criterion = "entropy")
dtc.fit(x_train,y_train)
dtc_pred = dtc.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,dtc_pred)))
print("RMSE: " + str(mean_squared_error(y_test,dtc_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,dtc_pred))
# Out:
# R^2 Score: -0.043576064112335056
# RMSE: 0.35109435617431917
# Confusion matrix:
# [[20963   457]
#  [ 2602   794]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100, criterion = "gini")
rfc.fit(x_train,y_train)
rfc_pred = rfc.predict(x_test)
#rfc_pred2 = rfc.predict(test_data)

print("R^2 Score: " + str(r2_score(y_test,rfc_pred)))
print("RMSE: " + str(mean_squared_error(y_test,rfc_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,rfc_pred))
# Out:
# R^2 Score: 0.035570600442768496
# RMSE: 0.33751805835586346
# Confusion matrix:
# [[21032   388]
#  [ 2439   957]]

# %%
asd = pd.Series(rfc_pred)
asd2 = pd.Series(rfc_pred2)
asd2.value_counts()
# Out:
# 0    16978
# dtype: int64

# %%
from xgboost import XGBClassifier #öncesinde install etmek gerekir
classifier = XGBClassifier()
classifier.fit(x_train, y_train)
xg_pred = classifier.predict(x_test)
#xg_pred2 = classifier.predict(test_data)

print("R^2 Score: " + str(r2_score(y_test,xg_pred)))
print("RMSE: " + str(mean_squared_error(y_test,xg_pred, squared=False)))
print("Confusion matrix:")
print(confusion_matrix(y_test,xg_pred))
# Out:
# R^2 Score: 0.04807918241240128
# RMSE: 0.21197447087305107
# Confusion matrix:
# [[36903   215]
#  [ 1540   400]]

# %%
# Out:
#         ACCMVMTAVG  ACCAMNTAVG03  ACCACVNUM12  ACCAMNTAVG12  CARDDINSUM12  \
# 1          50477.0     122.00000        100.0   6169.715125    100.000000
# 3           9723.0     111.00000        100.0   7173.000000    100.000000
# 4           2124.0   12339.37542        100.0   2498.000000   2232.150375
# 5            178.0     129.00000        100.0   6169.715125    162.000000
# 6           1138.0     870.00000        100.0    988.000000    173.000000
# ...            ...           ...          ...           ...           ...
# 173581      1205.0     150.00000        100.0    624.000000   2232.150375
# 173583      1869.0   12465.00000        100.0   2262.000000   2232.150375
# 173585       612.0     447.00000        100.0   2003.000000   2232.150375
# 173587      1529.0   18222.00000        100.0   7569.000000    189.000000
# 173588      1329.0    6218.00000        100.0    801.000000   2232.150375
#
#         DISTNUM12  INTPHNNUM03  INTLOGNUM12  DEMINFO1  DEMINFO2  CRRASTALL  \
# ...

# %% [markdown]
# ### StandardScaler kullanarak verilerimizi scale edelim

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
lr_pred = lr.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score

print("R^2 Score: " + str(r2_score(y_test,lr_pred)))
print("RMSE: " + str(mean_squared_error(y_test,lr_pred, squared=False)))

# %%
from sklearn.svm import LinearSVR
kernel = ["linear", "poly", "rbf", "sigmoid", "precomputed"]

svr = LinearSVR()
svr.fit(x_train,y_train)
svr_pred = svr.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,svr_pred)))
print("RMSE: " + str(mean_squared_error(y_test,svr_pred, squared=False)))

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(max_depth=None, criterion = "mse", min_samples_split = 2,min_samples_leaf= 7)
dtr.fit(x_train,y_train)
dtr_pred = dtr.predict(x_test)
dtr2_pred = dtr.predict(test_data)

print("R^2 Score: " + str(r2_score(y_test,dtr_pred)))
print("RMSE: " + str(mean_squared_error(y_test,dtr_pred, squared=False)))
# Out:
# R^2 Score: 0.06553404345655034
# RMSE: 10459.041965515678

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 100, criterion = "mse")
rfr.fit(x_train,y_train)
rfr_pred = rfr.predict(x_test)

print("R^2 Score: " + str(r2_score(y_test,rfr_pred)))
print("RMSE: " + str(mean_squared_error(y_test,rfr_pred, squared=False)))

# %%
output = pd.DataFrame({'Id': test_input["CUSTNBR"], 'Predicted': dtr2_pred})
output.to_csv('denemesub.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion="entropy")
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)

confusion_matrix(y_test,pred)
# Out:
# array([[43512,  3270],
#        [ 3128,  2167]], dtype=int64)

# %%
y_test[y_test==1]
# Out:
# 80728     1
# 9307      1
# 35837     1
# 31930     1
# 30863     1
#          ..
# 72599     1
# 32395     1
# 130182    1
# 117088    1
# 172636    1
# Name: ADDCONTAMNT, Length: 5295, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
confusion_matrix(y_test,y_pred)
# Out:
# array([[46280,   502],
#        [ 4253,  1042]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train =ss.fit_transform(x_train)
x_test =ss.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver="saga",penalty="l1",random_state = 0)
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)

confusion_matrix(y_test,y_pred)
